# %% [markdown]
# # Elbow Method

# %%
# Imports

import os
import sys

sys.path.append(os.path.abspath(".."))

from src.preprocessing import process_X
import pandas as pd
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
from sklearn.metrics import silhouette_score

# %%
# Data Load

df = pd.read_csv(r"C:\Users\sailj\OneDrive\文档\GitHub\Data-Driven Customer Segmentation\dataset\Online Retail.csv")

X = process_X(df)

X
# Out:
#       TotalPrice_max  TotalPrice_sum  Quantity_sum  Distinct_Product  \
# 0          26.634382        8.359634     14.445201         -0.708687
# 1           0.021123        0.251046      0.250006          0.486336
# 2           0.017802       -0.028546      0.226861         -0.462653
# 3           0.038557       -0.032963     -0.111417          0.134858
# 4          -0.051383       -0.191315     -0.197272         -0.521232
# ...              ...             ...           ...               ...
# 4334       -0.057021       -0.208429     -0.227341         -0.603243
# 4335       -0.059356       -0.219531     -0.225561         -0.638391
# 4336       -0.056399       -0.208712     -0.215867         -0.579812
# 4337       -0.058025        0.004572      0.040116          2.360880
# 4338       -0.035125       -0.024091      0.077504         -0.029164
#
#       Frequency  Avg_Product_Price
# 0     -0.424675          -0.059414
# 1      0.354080          -0.037931
# 2     -0.035297          -0.067612
# 3     -0.424675          -0.006860
# 4     -0.424675          -0.039617
# ...         ...                ...
# 4334  -0.424675           0.030116
# 4335  -0.424675          -0.045663
# 4336  -0.294882          -0.038678
# 4337   1.522213          -0.045576
# 4338  -0.165090          -0.055848
#
# [4339 rows x 6 columns]

# %%
# Training Models with different k

wcss = []
score = []


for k in range(2,11) :
    model = KMeans(
        n_clusters = k ,
        n_init = 10 ,
        random_state = 42
    )
    
    model.fit(X)
    wcss.append(model.inertia_)
    label = model.labels_
    score.append(silhouette_score(X , label))

# %%
# Elbow Curve 

plt.plot(range(2,11) , wcss)
plt.xlabel("no of Clusters (k)")
plt.ylabel("WCSS")
plt.title("Elbow Curve")
plt.grid()
plt.show()

# %%
# Silhouette Score Curve 

plt.plot(range(2,11) , score)
plt.xlabel("no of Clusters (k)")
plt.ylabel("Silhouette Score")
plt.title("Silhouette Score Curve")
plt.grid()
plt.show()

# %% [markdown]
# # Final Verdict
# # -------------------------------------------------------------------------------------------
# # The Elbow Method suggested 4–6 clusters. Although the Silhouette Score peaked at k=2, this primarily separated a small set of high-value customers from the rest. To obtain more actionable customer segments, k=4 was selected and the resulting clusters were analyzed.
